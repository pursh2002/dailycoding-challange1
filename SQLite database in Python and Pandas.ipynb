# %%
cd desktop
# Out:
# /Users/apple/Desktop

# %%
cd sqlite_file
# Out:
# /Users/apple/Desktop/sqlite_file

# %%
import sqlite3
import pandas as pd

# Create the connection
cnx = sqlite3.connect(r'/Users/apple/Desktop/sqlite_file/SQLDB.db')

# %%
df = pd.read_sql_query("SELECT * FROM countries", cnx)

# %%
df
# Out:
#              field1                field2      field3          field4  \
# 0           Country                Region  Population  Area (sq. mi.)
# 1       Afghanistan  ASIA (EX. NEAR EAST)    31056997          647500
# 2           Albania        EASTERN EUROPE     3581655           28748
# 3           Algeria       NORTHERN AFRICA    32930091         2381740
# 4    American Samoa               OCEANIA       57794             199
# ..              ...                   ...         ...             ...
# 223       West Bank             NEAR EAST     2460492            5860
# 224  Western Sahara       NORTHERN AFRICA      273008          266000
# 225           Yemen             NEAR EAST    21456188          527970
# 226          Zambia    SUB-SAHARAN AFRICA    11502010          752614
# 227        Zimbabwe    SUB-SAHARAN AFRICA    12236805          390580
#
#                          field5                        field6         field7  \
# ...

# %%
cur = cnx.cursor()
cur.execute('SELECT * from countries')

# %%
print(cur.fetchone())
# Out:
# ('Country', 'Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)', 'Net migration', 'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service')

# %%
print(cur.fetchall())
# Out:
# []

# %%
for row in cur.execute('SELECT * FROM countries'):
    print(row)
# Out:
# ('Country', 'Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)', 'Net migration', 'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service')
# ('Afghanistan', 'ASIA (EX. NEAR EAST)', '31056997', '647500', '48,0', '0,00', '23,06', '163,07', '700', '36,0', '3,2', '12,13', '0,22', '87,65', '1', '46,6', '20,34', '0,38', '0,24', '0,38')
# ('Albania', 'EASTERN EUROPE', '3581655', '28748', '124,6', '1,26', '-4,93', '21,52', '4500', '86,5', '71,2', '21,09', '4,42', '74,49', '3', '15,11', '5,22', '0,232', '0,188', '0,579')
# ('Algeria', 'NORTHERN AFRICA', '32930091', '2381740', '13,8', '0,04', '-0,39', '31', '6000', '70,0', '78,1', '3,22', '0,25', '96,53', '1', '17,14', '4,61', '0,101', '0,6', '0,298')
# ...

# %%
field1 = ('Afghanistan',)
cur.execute("SELECT * FROM countries WHERE field1 = '%s'" % field1)
print(cur.fetchone())
# Out:
# ('Afghanistan', 'ASIA (EX. NEAR EAST)', '31056997', '647500', '48,0', '0,00', '23,06', '163,07', '700', '36,0', '3,2', '12,13', '0,22', '87,65', '1', '46,6', '20,34', '0,38', '0,24', '0,38')

# %%
field1 = ('Afghanistan',)
cur.execute("SELECT * FROM countries WHERE field1 = ?", field1)
print(cur.fetchone())
# Out:
# ('Afghanistan', 'ASIA (EX. NEAR EAST)', '31056997', '647500', '48,0', '0,00', '23,06', '163,07', '700', '36,0', '3,2', '12,13', '0,22', '87,65', '1', '46,6', '20,34', '0,38', '0,24', '0,38')

# %%
import sqlite3
conn = sqlite3.connect(r'/Users/apple/Desktop/sqlite_file/consumers.db')
cur1 = conn.cursor()

# %%
df = pd.read_sql_query("SELECT * FROM consumers", conn)

# %%
df
# Out:
#    consumer_id  consumer_full_name   consumer_email  consumer_grade
# 0             1           John Doe  john.doe@xyz.com              A

# %%
cur1.execute("INSERT INTO consumers VALUES (1,'John Doe','john.doe@xyz.com','A')")
for row in cur1.execute('SELECT * FROM consumers'):
    print(row)
# Out:
# (1, 'John Doe', 'john.doe@xyz.com', 'A')
# (1, 'John Doe', 'john.doe@xyz.com', 'A')
# (1, 'John Doe', 'john.doe@xyz.com', 'A')

# %%
purchases = [(2,'John Paul','john.paul@xyz.com','B'),
             (3,'Chris Paul','john.paul@xyz.com','A'),
            ]

# Use executemany() to insert multiple records at a time
cur1.executemany('INSERT INTO consumers VALUES (?,?,?,?)', purchases)
for row in cur1.execute('SELECT * FROM consumers'):
    print(row)
# Out:
# (1, 'John Doe', 'john.doe@xyz.com', 'A')
# (1, 'John Doe', 'john.doe@xyz.com', 'A')
# (1, 'John Doe', 'john.doe@xyz.com', 'A')
# (2, 'John Paul', 'john.paul@xyz.com', 'B')
# (3, 'Chris Paul', 'john.paul@xyz.com', 'A')

# %%
conn.commit()

# %%
conn.close()

# %%
import sqlite3
conn = sqlite3.connect("/Users/apple/Desktop/sqlite_file/flights.db")

# %%
df = pd.read_sql_query("SELECT * FROM airlines", conn)

# %%
df
# Out:
#       index     id                                          name  \
# 0         0      1                                Private flight
# 1         1      2                                   135 Airways
# 2         2      3                                 1Time Airline
# 3         3      4  2 Sqn No 1 Elementary Flying Training School
# 4         4      5                               213 Flight Unit
# ...     ...    ...                                           ...
# 6043   6043  19828                                    Vuela Cuba
# 6044   6044  19830                                 All Australia
# 6045   6045  19831                                    Fly Europa
# 6046   6046  19834                                   FlyPortugal
# 6047   6047  19845                          FTI Fluggesellschaft
#
#               alias  iata  icao     callsign         country active
# 0                \N     -  None         None            None      Y
# ...

# %%
df1 = pd.read_sql_query("SELECT * FROM airports", conn)

# %%
df1
# Out:
#       index    id                               name             city  \
# 0         0     1                             Goroka           Goroka
# 1         1     2                             Madang           Madang
# 2         2     3                        Mount Hagen      Mount Hagen
# 3         3     4                             Nadzab           Nadzab
# 4         4     5         Port Moresby Jacksons Intl     Port Moresby
# ...     ...   ...                                ...              ...
# 8102   8102  9537    Mansons Landing Water Aerodrome  Mansons Landing
# 8103   8103  9538               Port McNeill Airport     Port McNeill
# 8104   8104  9539       Sullivan Bay Water Aerodrome     Sullivan Bay
# 8105   8105  9540               Deer Harbor Seaplane      Deer Harbor
# 8106   8106  9541  San Diego Old Town Transit Center        San Diego
#
#                country code  icao   latitude    longitude altitude offset dst  \
# ...

# %%
cur = conn.cursor()

# %%
cur.execute("select * from airlines limit 5;")

# %%
results = cur.fetchall()
print(results)
# Out:
# [(0, '1', 'Private flight', '\\N', '-', None, None, None, 'Y'), (1, '2', '135 Airways', '\\N', None, 'GNL', 'GENERAL', 'United States', 'N'), (2, '3', '1Time Airline', '\\N', '1T', 'RNX', 'NEXTIME', 'South Africa', 'Y'), (3, '4', '2 Sqn No 1 Elementary Flying Training School', '\\N', None, 'WYT', None, 'United Kingdom', 'N'), (4, '5', '213 Flight Unit', '\\N', None, 'TFU', None, 'Russia', 'N')]

# %%
coords = cur.execute("""
select cast(longitude as float),
cast(latitude as float)
from airports;""").fetchall()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
#!brew install geos
#!pip3 install https://github.com/matplotlib/basemap/archive/master.zip

# %%
m = Basemap(
projection='merc',
llcrnrlat=-80,
urcrnrlat=80,
llcrnrlon=-180,
urcrnrlon=180,
lat_ts=20,
resolution='c')
m.drawcoastlines()
m.drawmapboundary()

# %%
x, y = m([l[0] for l in coords],
[l[1] for l in coords])
m.scatter(x,y,1, marker='o',color='red')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-165-e671f0f3a610> in <module>
#       1 x, y = m([l[0] for l in coords],
#       2 [l[1] for l in coords])
# ----> 3 m.scatter(x,y,1, marker='o',color='red')
#
# /usr/local/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in with_transform(self, x, y, *args, **kwargs)
#     566             # convert lat/lon coords to map projection coords.
#     567             x, y = self(x,y)
# --> 568         return plotfunc(self,x,y,*args,**kwargs)
#     569     return with_transform
#     570
#
# /usr/local/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in scatter(self, *args, **kwargs)
#    3263         self.set_axes_limits(ax=ax)
#    3264         # clip to map limbs
# -> 3265         ret,c = self._cliplimb(ax,ret)
#    3266         return ret
#    3267
#
# ...

# %%
df["country"]
# Out:
# 0                 None
# 1        United States
# 2         South Africa
# 3       United Kingdom
# 4               Russia
#              ...
# 6043              Cuba
# 6044         Australia
# 6045             Spain
# 6046          Portugal
# 6047           Germany
# Name: country, Length: 6048, dtype: object

# %%
df1["country"]
# Out:
# 0       Papua New Guinea
# 1       Papua New Guinea
# 2       Papua New Guinea
# 3       Papua New Guinea
# 4       Papua New Guinea
#               ...
# 8102              Canada
# 8103              Canada
# 8104              Canada
# 8105       United States
# 8106       United States
# Name: country, Length: 8107, dtype: object

# %%
routes = pd.read_sql_query("""
select cast(sa.longitude as float) as source_lon,
cast(sa.latitude as float) as source_lat,
cast(da.longitude as float) as dest_lon,
cast(da.latitude as float) as dest_lat
from routes
inner join airports sa on sa.id = routes.source_id
inner join airports da on da.id = routes.dest_id;
""",
conn)

# %%
m = Basemap(
projection='merc',
llcrnrlat=-80,
urcrnrlat=80,
llcrnrlon=-180,
urcrnrlon=180,
lat_ts=20,
resolution='c'
)
m.drawcoastlines()

# %%
for name, row in routes[:3000].iterrows():
    if abs(row["source_lon"] - row["dest_lon"]) < 90:
         m.drawgreatcircle(
         row["source_lon"],
         row["source_lat"],
         row["dest_lon"],
         row["dest_lat"],
         linewidth=1,
         color='b'
         )
# Draw a great circle between source and dest airports.

# %%
pd.read_sql_query("select * from airlines where id=19830;", conn)
# Out:
#    index     id           name          alias iata icao callsign    country  \
# 0   6044  19830  All Australia  All Australia   88  8K8     None  Australia
#
#   active
# 0      Y

# %%
cur = conn.cursor()
cur.execute("insert into airlines values (6048, 19846, 'Test flight', '', '', null, null, null, 'Y')")

# %%
conn.commit()

# %%
pd.read_sql_query("select * from airlines where id=19846;", conn)
# Out:
#    index     id         name alias iata  icao callsign country active
# 0   6048  19846  Test flight             None     None    None      Y

# %%
# Passing parameters into a query

# %%
cur = conn.cursor()
name = "Test flight"
cur.execute("insert into airlines values (6049, 19847, {0}, '', '', null, null, null, 'Y')".format(name))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-200-d8e10ceee6a2> in <module>
#       1 cur = conn.cursor()
#       2 name = "Testflight"
# ----> 3 cur.execute("insert into airlines values (6049, 19847, {0}, '', '', null, null, null, 'Y')".format(name))
#
# OperationalError: no such column: Testflight

# %%
cur = conn.cursor()
values = ('Test Flight', 'Y')
cur.execute("insert into airlines values (6049, 19847, ?, '', '', null, null, null, ?)", values)
conn.commit()

# %%
# Updating rows

# %%
cur = conn.cursor()
values = ('USA', 19847)
cur.execute("update airlines set country=? where id=?", values)
conn.commit()

# %%
pd.read_sql_query("select * from airlines where id=19847;", conn)
# Out:
#    index     id         name alias iata  icao callsign country active
# 0   6049  19847  Test Flight             None     None     USA      Y

# %%
# Deleting rows

# %%
cur = conn.cursor() 
values = (19847, )
cur.execute("delete from airlines where id=?", values)
conn.commit()

# %%
pd.read_sql_query("select * from airlines where id=19847;", conn)
# Out:
# Empty DataFrame
# Columns: [index, id, name, alias, iata, icao, callsign, country, active]
# Index: []

# %%
# Creating tables

# %%
cur = conn.cursor()
cur.execute("create table daily_flights (id integer, departure date, arrival date, number text, route_id integer)")
conn.commit()

# %%
cur.execute("insert into daily_flights values (1, '2016-09-28 0:00', '2016-09-28 12:00', 'T1', 1)")
conn.commit()

# %%
pd.read_sql_query("select * from daily_flights;", conn)
# Out:
#    id        departure           arrival number  route_id
# 0   1  2016-09-28 0:00  2016-09-28 12:00     T1         1

# %%
# Creating tables with pandas

# %%
from datetime import datetime
df = pd.DataFrame(
[[1, datetime(2016, 9, 29, 0, 0) ,
datetime(2016, 9, 29, 12, 0), 'T1', 1]],
columns=["id", "departure", "arrival", "number", "route_id"])

# %%
df.to_sql("daily_flights", conn, if_exists="replace")

# %%
pd.read_sql_query("select * from daily_flights;", conn)
# Out:
#    index  id            departure              arrival number  route_id
# 0      0   1  2016-09-29 00:00:00  2016-09-29 12:00:00     T1         1

# %%
# Altering tables with Pandas

# %%
cur.execute("alter table airlines add column airplanes integer;")

# %%
pd.read_sql_query("select * from airlines limit 1;", conn)
# Out:
#    index id            name alias iata  icao callsign country active airplanes
# 0      0  1  Private flight    \N    -  None     None    None      Y      None

# %%
# Altering tables with Pandas

# %%
df = pd.read_sql("select * from daily_flights", conn)
df["delay_minutes"] = None
df.to_sql("daily_flights", conn, if_exists="replace")

# %%
df
# Out:
#    index  id            departure              arrival number  route_id  \
# 0      0   1  2016-09-29 00:00:00  2016-09-29 12:00:00     T1         1
#
#   delay_minutes
# 0          None
