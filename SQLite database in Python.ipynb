# %%
cd desktop
# Out:
# /Users/apple/Desktop

# %%
ls  agents.db
# Out:
# agents.db

# %%
import sqlite3
import pandas as pd

# %%
cnx = sqlite3.connect(r'/Users/apple/Desktop/Chinook_Sqlite.sqlite')

# %%
cnx

# %%
df = pd.read_sql_query("SELECT * FROM ALBUM", cnx)

# %%
df
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
cur = cnx.cursor()
cur.execute('select * from ALBUM')

# %%
print(cur.fetchone())
# Out:
# (1, 'For Those About To Rock We Salute You', 1)

# %%
print(cur.fetchall())
# Out:
# [(2, 'Balls to the Wall', 2), (3, 'Restless and Wild', 2), (4, 'Let There Be Rock', 1), (5, 'Big Ones', 3), (6, 'Jagged Little Pill', 4), (7, 'Facelift', 5), (8, 'Warner 25 Anos', 6), (9, 'Plays Metallica By Four Cellos', 7), (10, 'Audioslave', 8), (11, 'Out Of Exile', 8), (12, 'BackBeat Soundtrack', 9), (13, 'The Best Of Billy Cobham', 10), (14, 'Alcohol Fueled Brewtality Live! [Disc 1]', 11), (15, 'Alcohol Fueled Brewtality Live! [Disc 2]', 11), (16, 'Black Sabbath', 12), (17, 'Black Sabbath Vol. 4 (Remaster)', 12), (18, 'Body Count', 13), (19, 'Chemical Wedding', 14), (20, 'The Best Of Buddy Guy - The Millenium Collection', 15), (21, 'Prenda Minha', 16), (22, 'Sozinho Remix Ao Vivo', 16), (23, 'Minha Historia', 17), (24, 'Afrociberdelia', 18), (25, 'Da Lama Ao Caos', 18), (26, 'Acústico MTV [Live]', 19), (27, 'Cidade Negra - Hits', 19), (28, 'Na Pista', 20), (29, 'Axé Bahia 2001', 21), (30, 'BBC Sessions [Disc 1] [Live]', 22), (31, 'Bongo Fury', 23), (32, 'Carnaval 2001', 21), (33
# ...

# %%
for row in cur.execute('SELECT * FROM ALBUM'):
    print(row)
# Out:
# (1, 'For Those About To Rock We Salute You', 1)
# (2, 'Balls to the Wall', 2)
# (3, 'Restless and Wild', 2)
# (4, 'Let There Be Rock', 1)
# (5, 'Big Ones', 3)
# (6, 'Jagged Little Pill', 4)
# (7, 'Facelift', 5)
# (8, 'Warner 25 Anos', 6)
# (9, 'Plays Metallica By Four Cellos', 7)
# (10, 'Audioslave', 8)
# (11, 'Out Of Exile', 8)
# (12, 'BackBeat Soundtrack', 9)
# (13, 'The Best Of Billy Cobham', 10)
# (14, 'Alcohol Fueled Brewtality Live! [Disc 1]', 11)
# (15, 'Alcohol Fueled Brewtality Live! [Disc 2]', 11)
# (16, 'Black Sabbath', 12)
# (17, 'Black Sabbath Vol. 4 (Remaster)', 12)
# (18, 'Body Count', 13)
# (19, 'Chemical Wedding', 14)
# (20, 'The Best Of Buddy Guy - The Millenium Collection', 15)
# (21, 'Prenda Minha', 16)
# (22, 'Sozinho Remix Ao Vivo', 16)
# (23, 'Minha Historia', 17)
# (24, 'Afrociberdelia', 18)
# (25, 'Da Lama Ao Caos', 18)
# (26, 'Acústico MTV [Live]', 19)
# (27, 'Cidade Negra - Hits', 19)
# (28, 'Na Pista', 20)
# (29, 'Axé Bahia 2001', 21)
# ...

# %%
title = ('Balls to the Wall',)
cur.execute("SELECT * FROM ALBUM WHERE title = '%s'" % title)
print(cur.fetchone())
# Out:
# (2, 'Balls to the Wall', 2)

# %%
df = pd.read_sql_query("SELECT * FROM CUSTOMER", cnx)

# %%
df
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
FirstName = ('Luis',)
cur.execute("SELECT * FROM CUSTOMER WHERE FirstName = '%s'" % FirstName)
print(cur.fetchone())
# Out:
# (57, 'Luis', 'Rojas', None, 'Calle Lira, 198', 'Santiago', None, 'Chile', None, '+56 (0)2 635 4444', None, 'luisrojas@yahoo.cl', 5)

# %%
results = cur.fetchall()
print(results)
# Out:
# []

# %%
print(cur.fetchall())
# Out:
# []

# %%
cur.execute("SELECT LastName,Email FROM CUSTOMER WHERE FirstName = 'Daan' ")
print(cur.fetchone())
# Out:
# ('Peeters', 'daan_peeters@apple.be')

# %%
print(cur.fetchall())
# Out:
# []

# %%
cur.execute("SELECT LastName,Email FROM CUSTOMER WHERE Country = 'USA' GROUP BY LastName, email ")
print(cur.fetchone())
# Out:
# ('Barnett', 'jubarnett@gmail.com')

# %%
print(cur.fetchall())
# Out:
# [('Brooks', 'michelleb@aol.com'), ('Chase', 'kachase@hotmail.com'), ('Cunningham', 'ricunningham@hotmail.com'), ('Gordon', 'johngordon22@yahoo.com'), ('Goyer', 'tgoyer@apple.com'), ('Gray', 'patrick.gray@aol.com'), ('Harris', 'fharris@google.com'), ('Leacock', 'hleacock@gmail.com'), ('Miller', 'dmiller@comcast.com'), ('Ralston', 'fralston@gmail.com'), ('Smith', 'jacksmith@microsoft.com'), ('Stevens', 'vstevens@yahoo.com')]

# %%
cur.execute("SELECT LastName,Email FROM CUSTOMER WHERE Country = 'USA'")
print(cur.fetchone())
# Out:
# ('Harris', 'fharris@google.com')

# %%
print(cur.fetchall())
# Out:
# [('Smith', 'jacksmith@microsoft.com'), ('Brooks', 'michelleb@aol.com'), ('Goyer', 'tgoyer@apple.com'), ('Miller', 'dmiller@comcast.com'), ('Chase', 'kachase@hotmail.com'), ('Leacock', 'hleacock@gmail.com'), ('Gordon', 'johngordon22@yahoo.com'), ('Ralston', 'fralston@gmail.com'), ('Stevens', 'vstevens@yahoo.com'), ('Cunningham', 'ricunningham@hotmail.com'), ('Gray', 'patrick.gray@aol.com'), ('Barnett', 'jubarnett@gmail.com')]

# %%
cur.execute("SELECT a.* FROM CUSTOMER a JOIN (SELECT LastName, Email FROM CUSTOMER GROUP BY LastName, Email) b ON a.LastName = b.LastName AND a.Email = b.Email ORDER BY a.Email")

# %%
print(cur.fetchone())
# Out:
# (32, 'Aaron', 'Mitchell', None, '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', '+1 (204) 452-6452', None, 'aaronmitchell@yahoo.ca', 4)

# %%
title = ('Balls to the Wall',)
cur.execute("SELECT * FROM ALBUM WHERE title = '%s'" % title)
print(cur.fetchone())

# %%
cn = sqlite3.connect(r'/Users/apple/Desktop/agents.db')

# %%
cn

# %%
df = pd.read_sql_query("SELECT city, gender, MAX(age) AS max_age FROM elite_agent GROUP BY city;", cn)

# %%
df
# Out:
#        city gender  max_age
# 0   Chicago      M       27
# 1    Lisbon      F       27
# 2  New York      F       20

# %%
df1_avg = pd.read_sql_query("SELECT city, gender, Avg(age) AS mean_age FROM elite_agent GROUP BY city;",cn)

# %%
df1_avg
# Out:
#        city gender  mean_age
# 0   Chicago      F      23.0
# 1    Lisbon      M      22.5
# 2  New York      F      20.0

# %%
df1_all = pd.read_sql_query("SELECT* FROM elite_agent ", cn)

# %%
df1_all
# Out:
#    id      city gender  age
# 0   1    Lisbon      M   21
# 1   2   Chicago      F   20
# 2   3  New York      F   20
# 3   4   Chicago      M   27
# 4   5    Lisbon      F   27
# 5   6    Lisbon      M   19
# 6   7    Lisbon      F   23
# 7   8   Chicago      F   24
# 8   9   Chicago      M   21

# %%
df1_a = pd.read_sql_query("SELECT count(*) FROM elite_agent WHERE age IS NULL;",cn)

# %%
df1_a
# Out:
#    count(*)
# 0         0

# %%
username = "root"
password = "MyCar1973@"
port = 3306
database = "Shutterfly"
